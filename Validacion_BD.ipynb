# %% [markdown]
# ## Validación Base de Datos de SNPs

# %% [markdown]
# **1.-**  Lectura de la lista de muestras de validación (final_output_file) y crea un set.
#
# **2.-**  Búsqueda directa de la carpeta de cada muestra en samples_directory.
#
# **3.-**  Carga y filtrado del archivo snps.all.ivar.tsv original de cada muestra.
#
# **4.-**  Comparación de los SNPs filtrados con los de la BD (df_filtered_SNPs) usando merge por POS, REF, ALT.
#
# **5.-**  Adición de una columna CHECK_SAMPLES, solo si el sample_id aparece en la columna 'SAMPLES' de la BD.
#
# **6.-**  Adición de una columna de conteo CHECK_SAMPLES_COUNT.
#
# **7.-**  Guardado de un archivo TSV por muestra con los SNPs validados en output_directory.
#
# **8.-**  Comparación del número de SNPs por muestra generados tras la validación con los de su archivo tsv original.

# %%
import pandas as pd
import os
import random
import csv
import sys

# Aumentar el límite de campo de lectura csv al usar engine = 'python' para evitar error
csv.field_size_limit(sys.maxsize)

# Fijar semilla de números aleatorios
random.seed(0)

packs_directory = "/home/laura/andrea/scripts/TB_DDBB_Building/Paquetes_500_muestras"
samples_directory = "/media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants"
validation_directory = "/home/laura/andrea/scripts/TB_DDBB_Building/Validacion"
output_directory = "/home/laura/andrea/scripts/TB_DDBB_Building/Validacion/Validation_Samples_Files"

DDBB_file = "/home/laura/andrea/scripts/TB_DDBB_Building/Filtrado_SNPs/Filtered_SNPs_20250401_012139_raw_withComplex.tsv"

# DDBB en dataframe
df_filtered_SNPs = pd.read_csv(DDBB_file, sep='\t')

# %%
# Listado total de SNPs
total_SNPs = len(df_filtered_SNPs)
print("Número total de SNPs recogidos en la BBDD:")
print(total_SNPs)
print("--------------------------------------------------")
# Cálculo del 1% de SNPs totales de la BBDD
sampling_SNPs = max(1, int(0.01 * total_SNPs)) 
print("1% del total de SNPS:")
print(sampling_SNPs)
# Out:
# Número total de SNPs recogidos en la BBDD:
# 2264944
# --------------------------------------------------
# 1% del total de SNPS:
# 22649

# %%
# Hacer listado total de muestras
dir_list = os.listdir(samples_directory) 

output_list_file = "/home/laura/andrea/scripts/TB_DDBB_Building/DDBB_Samples_list"

with open(output_list_file, "w") as f:
    f.write("\n".join(dir_list))

# Leer el listado total de muestras
with open(output_list_file, "r") as f:
    total_samples = set(f.read().splitlines())

total_samples_lenght = len(total_samples)
print("Número total de muestras presentes en la BBDD:")
print(total_samples_lenght)
print("--------------------------------------------------")
# Cálculo del 1% de muestras totales de la BBDD
sampling_samples = max(1, int(0.01 * total_samples_lenght)) 
print("1% del total de muestras:")
print(sampling_samples)
print("--------------------------------------------------")
print("Número de muestras por paquete para la validación:")
print(sampling_samples / 222)
# Out:
# Número total de muestras presentes en la BBDD:
# 110899
# --------------------------------------------------
# 1% del total de muestras:
# 1108
# --------------------------------------------------
# Número de muestras por paquete para la validación:
# 4.990990990990991

# %%
pack_number = 1

for pack_file in sorted(os.listdir(packs_directory)):

    # Leer el listado total de 500 muestras en cada paquete
    with open(output_list_file, "r") as f:
        total_samples = set(f.read().splitlines())

    # Convertir en lista para evitar conflicto con random.sample
    total_samples_list = list(total_samples)

    # Seleccionar 5 muestras aleatorias por paquete
    validation_samples = set(random.sample(total_samples_list, 5))

    pack_file = os.path.join(validation_directory, f"Validation_Samples_pack_{pack_number}")

    with open(pack_file, "w") as f:
        f.write("\n".join(validation_samples))

    pack_number += 1

# %%
final_output_file = os.path.join(validation_directory, "All_Validation_Samples")

with open(final_output_file, "w") as outfile:

    for file in sorted(os.listdir(validation_directory)):

        if file.startswith("Validation_Samples_pack_"):

            file_path = os.path.join(validation_directory, file)
            
            with open(file_path, "r") as infile:
                outfile.write(infile.read())
                outfile.write("\n")  # Añadir salto de línea entre archivos si no está

# %%
with open(final_output_file, "r") as f:
    total_samples = set(f.read().splitlines())

# Para cada muestra en la lista, busca directamente su carpeta
for sample_id in total_samples:
    sample_folder = os.path.join(samples_directory, sample_id)

    print(sample_folder)
    
    if not os.path.isdir(sample_folder):
        print(f'Carpeta no encontrada para muestra: {sample_id}')
        continue

    tsv_file = os.path.join(sample_folder, "snps.all.ivar.tsv")

    if not os.path.isfile(tsv_file):
        print(f'Archivo TSV no encontrado para muestra: {sample_id}')
        continue

    try:
        df_file_sample = pd.read_csv(tsv_file, sep='\t')

        df_file_sample = df_file_sample.drop(columns=['ID', 'ALT_QUAL', 'FILTER', 'REF_DP', 
                                                'ALT_DP', 'REF_FREQ', 'OLDVAR', 'REGION'], errors = 'ignore')

        # Filtrado de SNPs por calidad:
        df_file_sample = df_file_sample[
            (df_file_sample['TOTAL_DP'] >= 20) & 
            (df_file_sample['ALT_FREQ'] >= 0.7) & 
            (df_file_sample['TYPE'] == "snp")]      

        # Se guardan solo los SNPs comunes entre la muestra y los de la BBDD
        matched_snps = df_file_sample.merge(df_filtered_SNPs, on=['POS', 'REF', 'ALT'], how='inner').drop(columns=['REGION'], errors='ignore')

        matched_snps['CHECK_SAMPLES'] = None

        for index, row in matched_snps.iterrows():
            if sample_id in row['SAMPLES']:
                matched_snps.at[index, 'CHECK_SAMPLES'] = f"{sample_id}-OK"

        # Agregar columna de conteo de chequeo
        matched_snps['CHECK_SAMPLES_COUNT'] = matched_snps['CHECK_SAMPLES'].apply(lambda x: len(x.split(", ")) if pd.notna(x) else 0)

        output_file = os.path.join(output_directory, f'SNPs_Validation_{sample_id}.tsv')
        matched_snps.to_csv(output_file, sep='\t', index=False)

        print(matched_snps)
        
    except Exception as e:
                print(f'Error procesando {sample_id}: {e}')
# Out:
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR26788508
#           POS REF ALT  TOTAL_DP TYPE  ALT_FREQ  \
# 0        1849   C   A        49  snp       1.0
# 1        2532   C   T        38  snp       1.0
# 2        9143   C   T        61  snp       1.0
# 3       11820   C   G        41  snp       1.0
# 4       13460   G   A        44  snp       1.0
# ...       ...  ..  ..       ...  ...       ...
# 1069  4395387   G   A        40  snp       1.0
# 1070  4397736   C   T        43  snp       1.0
# 1071  4401732   C   A        38  snp       1.0
# 1072  4407927   T   G        36  snp       1.0
# 1073  4408920   G   A        49  snp       1.0
#
#                                                 SAMPLES  COUNT  \
# 0     DRR019435, DRR019436, DRR019439, DRR034350, DR...  47800
# 1     20190732, DRR019439, DRR034350, DRR034374, DRR...  93060
# 2     20190732, DRR019439, DRR034350, DRR034371, DRR...  99283
# 3     DRR019435, DRR019436, DRR019439, DRR034350, DR...  40753
# 4     20190732, DRR019439, DRR034350, DRR034371, DRR...  99331
# ...                                                 ...    ...
# 1069  20190732, DRR019439, DRR034350, DRR034374, DRR...  98090
# 1070  DRR019435, DRR019436, DRR019439, DRR034350, DR...  48
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR19115694
#           POS REF ALT  TOTAL_DP TYPE  ALT_FREQ  \
# 0        1977   G   A       178  snp  0.994382
# 1        2532   C   T        70  snp  1.000000
# 2        2664   C   T        67  snp  0.985075
# 3        6262   G   A       254  snp  1.000000
# 4        7585   C   G       257  snp  1.000000
# ...       ...  ..  ..       ...  ...       ...
# 1131  4394506   C   T       475  snp  1.000000
# 1132  4395387   G   A       364  snp  0.991758
# 1133  4407588   C   T       193  snp  0.994819
# 1134  4408920   G   A       154  snp  0.974026
# 1135  4408923   T   C       154  snp  0.974026
#
#                                                 SAMPLES  COUNT  \
# 0     DRR034342, DRR034385, DRR034411, DRR034412, DR...   9411
# 1     20190732, DRR019439, DRR034350, DRR034374, DRR...  93060
# 2     DRR474002, ERR13264867, ERR13267757, ERR132855...     91
# 3                              SRR19115694, SRR19304017      2
# 4     DRR034342, DRR034385, DRR034411, DRR034412, DR...   9521
# ...                                                 ...    ...
# 1131  ERR028621, ERR108466, ERR108468, ERR11243613, ...    290
# 1132  20190732, DRR019439, DRR034350, DRR034374, DRR...  98090
# 1133  20190732, DRR034374, DRR034475, DRR188473, DRR...  50336
# 1134  20190732, DRR019439, DRR034350, DRR034371, DRR...  97524
# 1135  20190732, DRR034374, DRR034475, DRR188473, DRR...  49017
#
#        CHECK_SAMPLES  CHECK_SAMPLES_COUNT
# 0     SRR19115694-OK                    1
# 1     SRR19115694-OK                    1
# 2     SRR19115694-OK                    1
# 3     SRR19115694-OK                    1
# 4     SRR19115694-OK                    1
# ...              ...                  ...
# 1131  SRR19115694-OK                    1
# 1132  SRR19115694-OK                    1
# 1133  SRR19115694-OK                    1
# 1134  SRR19115694-OK                    1
# 1135  SRR19115694-OK                    1
#
# [1136 rows x 10 columns]

# %%
final_output_file = os.path.join(validation_directory, "All_Validation_Samples")

with open(final_output_file, "r") as f:
    total_samples = set(f.read().splitlines())

final_validation_file = pd.DataFrame()

results = []  # Lista de diccionarios que formará el DataFrame final

# Para cada muestra en la lista, busca directamente su carpeta
for sample_id in total_samples:
    print(f"Procesando muestra: {sample_id}")
    
    # Ruta a archivo tsv original
    sample_folder = os.path.join(samples_directory, sample_id)
    print(sample_folder)
    
    if not os.path.isdir(sample_folder):
        print(f'Carpeta no encontrada para muestra: {sample_id}')
        continue
    
    # Archivo tsv original de cada muestra:
    tsv_file = os.path.join(sample_folder, "snps.all.ivar.tsv")

    if not os.path.isfile(tsv_file):
        print(f'Archivo TSV no encontrado para muestra: {sample_id}')
        continue
    
    # Archivo de validación de cada muestra:
    tsv_file_validation = os.path.join(output_directory, f"SNPs_Validation_{sample_id}.tsv")

    if not os.path.isfile(tsv_file_validation):
        print(f'Archivo de validación TSV no encontrado para muestra: {sample_id}')
        continue

    try:
        # Lectura archivo original
        df_file_sample = pd.read_csv(tsv_file, sep='\t', engine='python')
        
        df_file_sample = df_file_sample.drop(columns=['ID', 'ALT_QUAL', 'FILTER', 'REF_DP', 
                                                'ALT_DP', 'REF_FREQ', 'OLDVAR', 'REGION'], errors = 'ignore')

        # Filtrado de SNPs por calidad:
        df_file_sample = df_file_sample[
            (df_file_sample['TOTAL_DP'] >= 20) & 
            (df_file_sample['ALT_FREQ'] >= 0.7) & 
            (df_file_sample['TYPE'] == "snp")]

        # Lectura archivo validación
        sample_validation_df = pd.read_csv(tsv_file_validation, sep='\t', engine='python')
    
        # Comparar si el archivo tsv original y el de validación tienen el mismo número de SNPs
        same_number_snps = "YES" if len(df_file_sample) == len(sample_validation_df) else "NO"
        print(f"Mismo número de SNPs: {same_number_snps}")

        # Validación de SNPs
        check_status = "OK"

        for index, row in sample_validation_df.iterrows():
            if (row['CHECK_SAMPLES'] != f"{sample_id}-OK" and row['CHECK_SAMPLES_COUNT'] != 1) in df_file_sample:
                check_status = "Fail"
                print("Hay SNPs no coincidentes.")
                print(row['POS'], row['REF'], row['ALT'])
            
        if check_status == "OK":
            print("Todos los SNPs coinciden. Muestra validada.")

        results.append({'SAMPLE_ID': sample_id, 'Same_Number_SNPs': same_number_snps, 'Check_Sample': check_status})

    except Exception as e:
        print(f"Error procesando la muestra {sample_id}: {e}")
        results.append({'SAMPLE_ID': sample_id, 'Same_Number_SNPs': 'ERROR', 'Check_Sample': 'ERROR'})

# Guardar el diccionario en un dataframe
final_validation_file = pd.DataFrame(results)

output_file = os.path.join(validation_directory, f'Final_TB_DDBB_Validation.tsv')
final_validation_file.to_csv(output_file, sep='\t', index=False)
# Out:
# Procesando muestra: SRR12882329
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR12882329
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: ERR10112875
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/ERR10112875
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR28859758
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR28859758
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: ERR6358861
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/ERR6358861
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: ERR5864736
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/ERR5864736
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra:
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/
# Archivo TSV no encontrado para muestra:
# Procesando muestra: ERR2027305
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/ERR2027305
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR1140924
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR1140924
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR28240079
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR28240079
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: ERR4553831
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/ERR4553831
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: ERR7361981
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/ERR7361981
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: ERR13246443
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/ERR13246443
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR23316591
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR23316591
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: ERR12916916
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/ERR12916916
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: ERR13288858
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/ERR13288858
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR5341407
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR5341407
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR11348169
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR11348169
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR14801765
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR14801765
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR24256366
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR24256366
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR11662505
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR11662505
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR6398002
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR6398002
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: ERR13259950
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/ERR13259950
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR22251910
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR22251910
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: ERR9901825
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/ERR9901825
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR2502796
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR2502796
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR26399895
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR26399895
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: ERR13292278
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/ERR13292278
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: ERR221551
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/ERR221551
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: ERR13249746
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/ERR13249746
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR19428600
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR19428600
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR29681263
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR29681263
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR26399316
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR26399316
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR4034720
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR4034720
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR1144808
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR1144808
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR26111980
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR26111980
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR12882008
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR12882008
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: ERR13288912
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/ERR13288912
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR16103900
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR16103900
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: ERR9786960
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/ERR9786960
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: ERR10969212
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/ERR10969212
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: ERR11774856
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/ERR11774856
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR6280251
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR6280251
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR22424945
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR22424945
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR15723310
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR15723310
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR12080293
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR12080293
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR28389889
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR28389889
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR4037670
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR4037670
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR29538950
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR29538950
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR29053058
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR29053058
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR29356743
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR29356743
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR21733139
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR21733139
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR14164683
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR14164683
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR2502813
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR2502813
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR24256053
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR24256053
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR4034322
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR4034322
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR29056182
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR29056182
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR21677059
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR21677059
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR22424767
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR22424767
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR29231718
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR29231718
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR29539314
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR29539314
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR10525340
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR10525340
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: ERR13284778
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/ERR13284778
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR2024894
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR2024894
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR23340166
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR23340166
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: ERR234575
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/ERR234575
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: ERR5908195
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/ERR5908195
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR6397328
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR6397328
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR26112293
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR26112293
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR28239986
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR28239986
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: ERR5863708
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/ERR5863708
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR29126529
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR29126529
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: ERR12790843
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/ERR12790843
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR29052901
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR29052901
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: ERR13093939
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/ERR13093939
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR4033959
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR4033959
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR26795745
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SRR26795745
# Mismo número de SNPs: YES
# Todos los SNPs coinciden. Muestra validada.
# Procesando muestra: SRR30443888
# /media/NASII/Datos/ANALYSIS/Proyectos/BBDD_TB/AncestorII/Illumina/Variants/SR